# %% [markdown]
# <a href="https://colab.research.google.com/github/Xeesto/UEP/blob/main/Lecture-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Xeesto/UEP
# Out:
# Cloning into 'UEP'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !git clone https://github.com/Xeesto/UEP-lecture1
# Out:
# Cloning into 'UEP-lecture1'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 39.90 KiB | 907.00 KiB/s, done.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URL do surowych danych na GitHub
url = 'https://raw.githubusercontent.com/Xeesto/UEP/main/Salary%20Data%20(2).csv'

# Wczytanie danych z obsługą problemów
df = pd.read_csv(url)

# Sprawdzenie brakujących wartości
print("Liczba brakujących wartości w kolumnach:\n", df.isnull().sum())

# Usunięcie wierszy z brakującymi wartościami (opcjonalnie)
df.dropna(inplace=True)

# Konwersja kolumn na odpowiednie typy, jeśli to konieczne
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

print("Kolumny w zbiorze danych:", df.columns)

# Wykres zależności między latami doświadczenia a wynagrodzeniem
plt.figure(figsize=(8, 5))
plt.scatter(df['Age'], df['Salary'], color='black', alpha=0.5)
plt.xlabel('Wiek')
plt.ylabel('Wynagrodzenie')
plt.title('Zależność między wiekiem a wynagrodzeniem')
plt.grid()
plt.show()
# Out:
# Liczba brakujących wartości w kolumnach:
#  Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64
# Kolumny w zbiorze danych: Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')
